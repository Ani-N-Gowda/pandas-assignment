# %%
import pandas as pd
df=pd.read_excel("Downloads/casestudy.xlsx")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    860-79-0874      C  Naypyitaw        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    687-47-8271      A     Yangon        Normal    Male
# 4    283-26-5248      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  236-86-3015      C  Naypyitaw        Member    Male
# 996  192-98-7397      C  Naypyitaw        Normal    Male
# 997  279-62-1445      C  Naypyitaw        Member  Female
# 998  308-39-1707      A     Yangon        Normal  Female
# 999  784-21-9238      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  Day  \
# 0       Fashion accessories       99.30        10  49.6500  1042.6500    6
# 1    Electronic accessories       15.28         5   3.8200    80.2200    6
# ...

# %%
df.shape#shape
# Out:
# (1000, 18)

# %%
df.dtypes#dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Day                                 int64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df.isnull()#check missing values
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total    Day   Date   Time  Payment   cogs  \
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    860-79-0874      C  Naypyitaw        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    687-47-8271      A     Yangon        Normal    Male
# 4    283-26-5248      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  236-86-3015      C  Naypyitaw        Member    Male
# 996  192-98-7397      C  Naypyitaw        Normal    Male
# 997  279-62-1445      C  Naypyitaw        Member  Female
# 998  308-39-1707      A     Yangon        Normal  Female
# 999  784-21-9238      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  Day  \
# 0       Fashion accessories       99.30        10  49.6500  1042.6500    6
# 1    Electronic accessories       15.28         5   3.8200    80.2200    6
# ...

# %%
new_df=df.fillna(method="ffill")
new_df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    860-79-0874      C  Naypyitaw        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    687-47-8271      A     Yangon        Normal    Male
# 4    283-26-5248      C  Naypyitaw        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  236-86-3015      C  Naypyitaw        Member    Male
# 996  192-98-7397      C  Naypyitaw        Normal    Male
# 997  279-62-1445      C  Naypyitaw        Member  Female
# 998  308-39-1707      A     Yangon        Normal  Female
# 999  784-21-9238      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%      Total  Day  \
# 0       Fashion accessories       99.30        10  49.6500  1042.6500    6
# 1    Electronic accessories       15.28         5   3.8200    80.2200    6
# ...

# %%
df.count()
# Out:
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Day                        1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
df.count(axis=1)
# Out:
# 0      18
# 1      18
# 2      18
# 3      18
# 4      18
#        ..
# 995    18
# 996    18
# 997    18
# 998    18
# 999    18
# Length: 1000, dtype: int64

# %%
df.value_counts(df['Branch'].values)
# Out:
# A    340
# B    332
# C    328
# dtype: int64

# %%
df.value_counts(df['City'])
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# dtype: int64

# %%
df.value_counts(df['Gender'])
# Out:
# Gender
# Female    501
# Male      499
# dtype: int64

# %%
df.value_counts(df['Product line'])
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# dtype: int64

# %%
df.value_counts(df['Customer type'])
# Out:
# Customer type
# Member    501
# Normal    499
# dtype: int64

# %%
df.value_counts(df['Payment'])
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# dtype: int64

# %%
df.Branch.count()#total branch count
# Out:
# 1000

# %%
df.Branch.max()
# Out:
# 'C'

# %%
df.Branch.min()
# Out:
# 'A'
